# %% [markdown]
# <a href="https://colab.research.google.com/github/Avisweta-De/Toy-dataset-practice/blob/main/Ml_project_1_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/content/drive/My Drive/Colab Notebooks/placement.csv')

# %%
import os

path = "/content/drive/My Drive/Colab Notebooks"
files = os.listdir(path)

for file in files:
    print(file)
# Out:
# Untitled0.ipynb
# Untitled
# Untitled1.ipynb
# Dynamic Pricing for Urban Parking Lots.ipynb
# placement.csv
# Ml project 1 campusx.ipynb

# %%
df.head() #give the overview of the data by showing few columns
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
df.shape #shows dimension of the data set (rows,columns)
# Out:
# (100, 4)

# %%
df = df.iloc[:,1:] # "Keep all the rows, but drop the first column" from the DataFrame df.

# %%
df.head()
# Out:
#    cgpa     iq  placement
# 0   6.8  123.0          1
# 1   5.9  106.0          0
# 2   5.3  121.0          0
# 3   7.4  132.0          1
# 4   5.8  142.0          0

# %%
""" steps:
0: Preprocess+EDA+Feature Selection
1:Extract input and output cols
2:Scale the values
3: Train test split
4.Train the model
5.Evaluate the model/model selection
6.Deploy """

# %%
#info gives information about all column
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   iq         100 non-null    float64
#  1   placement  100 non-null    int64
# dtypes: float64(1), int64(1)
# memory usage: 1.7 KB

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['cgpa'],df['iq'])

# %%
plt.scatter(df['cgpa'],df['iq'],c=df['placement'])  # It has colour coded showing whether placement happened or not

# %%
x=df.iloc[:,0:2] #saare rows chahiye and 0 and 1 wala or last col chahiye
y=df.iloc[:,-1] #saare rows chahiye and -1 wala or last col chahiye

# %%
x
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]

# %%
y
# Out:
# 0     1
# 1     0
# 2     0
# 3     1
# 4     0
#      ..
# 95    0
# 96    0
# 97    1
# 98    1
# 99    1
# Name: placement, Length: 100, dtype: int64

# %%
x.shape #2D tensor or matrix
# Out:
# (100, 2)

# %%
y.shape #1D tensor
# Out:
# (100,)

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.1)

# %%
x_train
# Out:
#     cgpa     iq
# 15   5.1  176.0
# 72   7.3  116.0
# 79   6.5   90.0
# 29   7.0  112.0
# 33   6.0  149.0
# ..   ...    ...
# 47   5.2  161.0
# 99   6.2  113.0
# 90   7.3   86.0
# 96   4.4   42.0
# 30   7.6  128.0
#
# [90 rows x 2 columns]

# %%
y_train
# Out:
# 15    0
# 72    1
# 79    1
# 29    1
# 33    0
#      ..
# 47    0
# 99    1
# 90    1
# 96    0
# 30    1
# Name: placement, Length: 90, dtype: int64

# %%
x_test
# Out:
#     cgpa     iq
# 14   6.1  103.0
# 51   4.8  141.0
# 80   4.9  196.0
# 55   7.8  114.0
# 94   4.7   52.0
# 54   6.4  141.0
# 11   6.9  138.0
# 71   6.1  132.0
# 88   4.4  149.0
# 0    6.8  123.0

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
x_train=scaler.fit_transform(x_train)

# %%
x_train
# Out:
# array([[-7.88879131e-01,  1.31837897e+00],
#        [ 1.13474240e+00, -1.73812695e-01],
#        [ 4.35243659e-01, -8.20429082e-01],
#        [ 8.72430370e-01, -2.73292140e-01],
#        [-1.94305205e-03,  6.46892719e-01],
#        [-7.01441789e-01,  2.24105081e-01],
#        [-1.75068990e+00, -1.19347700e+00],
#        [ 6.10118343e-01,  7.71242024e-01],
#        [-7.88879131e-01, -1.41730575e+00],
#        [-1.75068990e+00, -5.71730472e-01],
#        [ 8.72430370e-01, -1.46704547e+00],
#        [-9.63753816e-01,  7.96111885e-01],
#        [ 9.59867712e-01,  6.96632441e-01],
#        [ 1.83424113e+00,  1.06968036e+00],
#        [-1.13862850e+00, -4.94633903e-02],
#        [-2.64255079e-01,  4.97673553e-01],
#        [ 1.39705442e+00, -8.45298944e-01],
#        [ 1.30961708e+00, -1.54165505e+00],
#        [-1.05119116e+00,  1.14428994e+00],
#        [ 2.60368974e-01,  1.24625637e-01],
#        [-1.94305205e-03, -1.93957283e+00],
#        [ 2.60368974e-01,  9.97557759e-02],
#        [-5.26567105e-01, -3.97641445e-01],
#        [ 4.35243659e-01, -2.13853172e+00],
#        [-2.64255079e-01,  1.14428994e+00],
#        [ 4.35243659e-01,  9.20461190e-01],
#        [ 7.84993027e-01, -6.71209916e-01],
#        [ 5.22681001e-01,  3.73324247e-01],
#        [ 1.13474240e+00, -1.81522352e+00],
#        [-1.83812724e+00, -3.47901723e-01],
#        [-8.76316474e-01, -7.95559221e-01],
#        [ 6.97555685e-01, -2.73292140e-01],
